# %% [markdown]
# <a href="https://colab.research.google.com/github/sku1978/pycode/blob/master/ML/KMeans/KMeans%20with%20Generated%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(n_samples=2000, n_features=2, centers=4, cluster_std=1.6, random_state=101)

# %%
data[0]
# Out:
# array([[ -5.95338136,  -7.99827109],
#        [ -1.42765628,  -0.48537934],
#        [ -7.21128244,  -7.23134573],
#        ...,
#        [-13.05722947,  -7.34279013],
#        [ -3.68008831,   8.17030373],
#        [ -3.79959574,   8.34040074]])

# %%
print(data[0].shape, data[1].shape)
# Out:
# (2000, 2) (2000,)

# %%
sns.scatterplot(x=data[0][:,0], y=data[0][:,1], hue=data[1])

# %%
from sklearn.cluster import KMeans

# %%
import ipywidgets as widgets
slider = widgets.IntSlider(value=5, max=20)
display(slider)
# Out:
# IntSlider(value=5, max=20)

# %%
km=KMeans(n_clusters=slider.value, max_iter=400)
km.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=400,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
km.cluster_centers_
# Out:
# array([[-9.35395272, -6.49727816],
#        [-3.81600098,  7.83770718],
#        [ 0.45409504,  1.34653404],
#        [ 3.86294303,  6.76712138]])

# %%
km.labels_
# Out:
# array([0, 2, 0, ..., 0, 1, 1], dtype=int32)

# %%
fig, ax=plt.subplots(1,2,figsize=(10,6), sharey=True)

ax[0].set_title('Original')
ax[1].set_title('KMeans')

sns.scatterplot(x=data[0][:,0], y=data[0][:,1], hue=data[1], ax=ax[0])
sns.scatterplot(x=data[0][:,0], y=data[0][:,1], hue=km.labels_, ax=ax[1], palette='rocket')
